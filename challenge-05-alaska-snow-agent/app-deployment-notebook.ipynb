# %% [markdown]
# ### Intitial Pull

# %%
  # Clone the repository
# !git clone -b final_challenge https://github.com/tim-gameplan/genai-skills-workshop-tim-beermann.git
# Out:
# Cloning into 'genai-skills-workshop-tim-beermann'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 133 (delta 41), reused 128 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (133/133), 308.92 KiB | 4.29 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %% [markdown]
# ### Pull Updates

# %%
# Pull the latest changes from final_challenge branch
# !git pull origin final_challenge
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 907 bytes | 453.00 KiB/s, done.
# From https://github.com/tim-gameplan/genai-skills-workshop-tim-beermann
#  * branch            final_challenge -> FETCH_HEAD
#    41dc6ed..54c4ce0  final_challenge -> origin/final_challenge
# Updating 41dc6ed..54c4ce0
# Fast-forward
#  challenge-05-alaska-snow-agent/deployment/app.py | 15 +++++++++++----
#  1 file changed, 11 insertions(+), 4 deletions(-)

# %% [markdown]
# ### Be in the correct directory

# %%
# Navigate to deployment directory
# %cd genai-skills-workshop-tim-beermann/challenge-05-alaska-snow-agent/deployment
# Out:
# /content/genai-skills-workshop-tim-beermann/challenge-05-alaska-snow-agent/deployment

# %% [markdown]
# ### Deploy the Magic

# %%
# Deploy with BOTH PROJECT_ID and GOOGLE_MAPS_API_KEY
# !gcloud run deploy alaska-snow-agent \
  --source . \
  --region us-central1 \
  --platform managed \
  --allow-unauthenticated \
  --timeout 300 \
  --set-env-vars PROJECT_ID=qwiklabs-gcp-03-ba43f2730b93,GOOGLE_MAPS_API_KEY=AIzaSyBGfv7HjI3xV5Rb07bWELKX5OxIkqpJ0SM \
  --quiet
# Out:
# Building using Dockerfile and deploying container to Cloud Run service [alaska-snow-agent] in project [qwiklabs-gcp-03-ba43f2730b93] region [us-central1]
# Service [alaska-snow-agent] revision [alaska-snow-agent-00006-jvj] has been deployed and is serving 100 percent of traffic.
# Service URL: https://alaska-snow-agent-281600971548.us-central1.run.app

# %%
# View the deployment logs
# !gcloud logging read "resource.type=cloud_run_revision AND resource.labels.service_name=alaska-snow-agent" \
  --limit 50 \
  --format "table(timestamp, textPayload)" \
  --project qwiklabs-gcp-03-ba43f2730b93
# Out:
# TIMESTAMP                    TEXT_PAYLOAD
# 2025-12-04T00:31:01.930305Z
# 2025-12-04T00:31:01.929981Z
# 2025-12-04T00:31:01.778052Z    Stopping...
# 2025-12-04T00:31:01.778050Z  [2025-12-04 00:21:59] [WARN] Google Maps API key not configured
# 2025-12-04T00:31:01.778048Z  [2025-12-04 00:21:59] [FUNCTION_CALL] Gemini requested: get_weather_forecast({'location': 'Anchorage'})
# 2025-12-04T00:31:01.778044Z  [2025-12-04 00:21:59] [GENERATION] Sending to Gemini 2.5 Flash with function calling...
# 2025-12-04T00:31:01.778042Z  [2025-12-04 00:21:59] [RETRIEVAL] Found 3 relevant entries
# 2025-12-04T00:31:01.778040Z  [2025-12-04 00:21:57] [CHAT_START] Query: What is the weather forecast for Anchorage Alaska?
# 2025-12-04T00:31:01.778038Z  [2025-12-04 00:21:35] [CHAT_END] Response sent
# 2025-12-04T00:31:01.778035Z  [2025-12-04 00:21:34] [GENERATION] Sending to Gemini 2.5 Flash with function calling...
# 2025-12-04T00:31:01.778033Z  [2025-12-04 00:21:34] [RETRIEVAL] Found 3 relevant entries
# ...

# %%
# !bq query --use_legacy_sql=false \
--project_id=qwiklabs-gcp-03-ba43f2730b93 \
"SELECT question, answer FROM \`qwiklabs-gcp-03-ba43f2730b93.alaska_snow_capstone.snow_faqs_raw\` LIMIT 10"
# Out:
# +------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                             question                             |                                                                                  answer                                                                                   |
# +------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | When was the Alaska Department of Snow established?              | The Alaska Department of Snow (ADS) was established in 1959, coinciding with Alaska’s admission as a U.S. state.                                                          |
# ...
